# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
cr_df=pd.read_csv(r"C:\Users\DELL 7420 I7 11THGEN\Documents\Python_Handson\ds_class\customer_reviews.csv")
cr_df
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2025-06-20       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# ..       ...         ...        ...         ...     ...
# 95        96          19         13  2023-09-02       3
# 96        97          64          6  2024-01-19       3
# 97        98          96          3  2025-11-20       5
# 98        99          79         16  2025-01-29       2
# 99       100           9          2  2025-06-20       3
#
#                                            ReviewText
# 0             Average  experience,  nothing  special.
# 1                      The  quality  is    top-notch.
# 2             Five  stars  for  the  quick  delivery.
# 3            Good  quality,  but  could  be  cheaper.
# ...

# %%
cj_df=pd.read_csv(r"C:\Users\DELL 7420 I7 11THGEN\Documents\Python_Handson\ds_class\customer_journey.csv")
cj_df
# Out:
#     JourneyID  CustomerID  ProductID   VisitDate        Stage    Action  \
# 0           1          64         18  2024-06-10     Checkout  Drop-off
# 1           2          94         11  2025-07-09     Checkout  Drop-off
# 2           3          34          8  2024-06-14  ProductPage      View
# 3           4          33         18  2025-05-28     Checkout  Drop-off
# 4           5          91         10  2023-02-11     Homepage     Click
# ..        ...         ...        ...         ...          ...       ...
# 95         96          22          9  2024-07-28  ProductPage      View
# 96         97          92         19  2025-05-26     homepage      View
# 97         98          95          8  2025-05-25     Homepage     Click
# 98         99          58         16  2024-07-06     Checkout  Purchase
# 99        100          92         10  2024-04-06  ProductPage      View
#
#     Duration
# 0      235.0
# 1      156.0
# 2      235.0
# 3        NaN
# 4      156.0
# ..       ...
# ...

# %%
customer_df=pd.read_csv(r"C:\Users\DELL 7420 I7 11THGEN\Documents\Python_Handson\ds_class\customers.csv")
customer_df
# Out:
#     CustomerID      CustomerName                         Email  Gender  Age  \
# 0            1     Emma Anderson     emma.anderson@example.com    Male   50
# 1            2       Sarah Brown       sarah.brown@example.com  Female   37
# 2            3  Robert Hernandez  robert.hernandez@example.com  Female   26
# 3            4      David Garcia      david.garcia@example.com    Male   25
# 4            5       Emma Miller       emma.miller@example.com  Female   41
# ..         ...               ...                           ...     ...  ...
# 95          96    Emily Gonzalez    emily.gonzalez@example.com  Female   38
# 96          97   Emily Rodriguez   emily.rodriguez@example.com  Female   51
# 97          98       Chris Lopez       chris.lopez@example.com  Female   55
# 98          99   Laura Hernandez   laura.hernandez@example.com    Male   41
# 99         100        Jane Brown        jane.brown@example.com  Female   45
#
#     GeographyID
# 0             2
# 1             4
# ...

# %%
engagementdata_df=pd.read_csv(r"C:\Users\DELL 7420 I7 11THGEN\Documents\Python_Handson\ds_class\engagement_data.csv")
engagementdata_df
# Out:
#     EngagementID  ContentID ContentType  Likes EngagementDate  CampaignID  \
# 0              1         39        Blog    190     2023-08-30           1
# 1              2         48        Blog    114     2023-03-28          18
# 2              3         16       video     32     2023-12-08           7
# 3              4         43       Video     17     2025-01-21          19
# 4              5         16  newsletter    306     2024-02-21           6
# ..           ...        ...         ...    ...            ...         ...
# 95            96         17        Blog     32     2024-07-15          14
# 96            97         34        blog      3     2025-07-01          16
# 97            98         44        blog      0     2025-08-20          11
# 98            99         26        Blog    119     2024-04-15          17
# 99           100         32       Video     34     2024-05-05          15
#
#     ProductID ViewsClicksCombined
# 0           9            1883-671
# ...

# %%
geography_df=pd.read_csv(r"C:\Users\DELL 7420 I7 11THGEN\Documents\Python_Handson\ds_class\geography.csv")
geography_df
# Out:
#    GeographyID      Country       City
# 0            1           UK     London
# 1            2      Germany     Berlin
# 2            3       France      Paris
# 3            4        Spain     Madrid
# 4            5        Italy       Rome
# 5            6  Netherlands  Amsterdam
# 6            7      Belgium   Brussels
# 7            8       Sweden  Stockholm
# 8            9  Switzerland     Zurich
# 9           10      Austria     Vienna

# %%
products_df=pd.read_csv(r"C:\Users\DELL 7420 I7 11THGEN\Documents\Python_Handson\ds_class\products.csv")
products_df
# Out:
#     ProductID      ProductName Category   Price
# 0           1    Running Shoes   Sports  223.75
# 1           2  Fitness Tracker   Sports  196.68
# 2           3         Yoga Mat   Sports  485.32
# 3           4        Dumbbells   Sports   26.21
# 4           5      Soccer Ball   Sports   41.26
# 5           6    Tennis Racket   Sports   36.07
# 6           7       Basketball   Sports  225.12
# 7           8  Football Helmet   Sports   44.75
# 8           9   Baseball Glove   Sports  327.36
# 9          10       Golf Clubs   Sports   81.59
# 10         11        Ski Boots   Sports  340.20
# 11         12       Ice Skates   Sports   37.56
# 12         13     Swim Goggles   Sports  145.97
# 13         14   Cycling Helmet   Sports  472.32
# 14         15    Climbing Rope   Sports  410.17
# 15         16            Kayak   Sports  259.40
# 16         17        Surfboard   Sports  275.43
# 17         18       Volleyball   Sports   42.80
# 18         19     Hockey Stick   Sports  173.83
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
connection = mysql.connector.connect(
        host="localhost",
        port=3306,
        user="root",
        password="root",
        database="customer_behaviour_analysis" )

cursor = connection.cursor()

# %%
cursor.execute("""
    CREATE TABLE if not exists customer_journey  (
        JourneyID INT ,
        CustomerID INT,
        ProductID INT,
        VisitDate DATE,
        Stage VARCHAR(25),
        Action VARCHAR(25),
        Duration FLOAT
    )
""")

# %%
cj_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   JourneyID   100 non-null    int64
#  1   CustomerID  100 non-null    int64
#  2   ProductID   100 non-null    int64
#  3   VisitDate   100 non-null    object
#  4   Stage       100 non-null    object
#  5   Action      100 non-null    object
#  6   Duration    88 non-null     float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.6+ KB

# %%
cj_df=cj_df.fillna(0.0)

# %%
for index, row in cj_df.iterrows():
      cursor.execute("""  
            insert into customer_journey(JourneyID,CustomerID,ProductID,VisitDate,Stage,Action,Duration)
            values (%s,%s,%s,%s,%s,%s,%s) 
      """,(row['JourneyID'], row['CustomerID'], row['ProductID'], row['VisitDate'],row['Stage'],row['Action'],row['Duration']))
connection.commit()       # connection.commit() saves all changes permanently

# %%
connection.commit()

# %%
cursor.execute("""CREATE TABLE customer_reviews (
                                        ReviewID INT ,
                                        CustomerID INT,
                                        ProductID INT,
                                        ReviewDate DATE,
                                        Rating INT,
                                        ReviewText VARCHAR(200)
                                    );""")

# %%
cr_df.columns
# Out:
# Index(['ReviewID', 'CustomerID', 'ProductID', 'ReviewDate', 'Rating',
#        'ReviewText'],
#       dtype='object')

# %%
for index, row in cr_df.iterrows():
      values = (row['ReviewID'],row['CustomerID'], row['ProductID'], row['ReviewDate'],row['Rating'],row['ReviewText'])
      print(values)
# Out:
# (1, 77, 18, '2025-06-20', 3, 'Average  experience,  nothing  special.')
# (2, 80, 19, '2024-12-25', 5, 'The  quality  is    top-notch.')
# (3, 50, 13, '2025-01-26', 4, 'Five  stars  for  the  quick  delivery.')
# (4, 78, 15, '2025-04-21', 3, 'Good  quality,  but  could  be  cheaper.')
# (5, 64, 2, '2023-07-16', 3, 'Average  experience,  nothing  special.')
# (6, 81, 1, '2025-12-21', 4, 'Customer  support  was  very  helpful.')
# (7, 16, 1, '2024-01-29', 3, 'Average  experience,  nothing  special.')
# (8, 55, 8, '2024-08-15', 5, 'The  quality    is  top-notch.')
# (9, 3, 13, '2023-09-01', 4, 'I  love  this  product,  will  buy  again!')
# (10, 78, 6, '2024-06-17', 5, 'Excellent  product,  highly  recommend!')
# (11, 54, 9, '2023-07-17', 4, 'Great  purchase,  very  satisfied.')
# (12, 77, 2, '2025-01-13', 2, 'Product  did    not  meet  my  expectations.')
# (13, 93, 6, '2024-08-20', 5, 'Great  purchase,  very  satisfied.')
# ...

# %%
insert_query = """INSERT INTO customer_reviews (ReviewID, CustomerID, ProductID, ReviewDate, Rating, ReviewText) 
VALUES (%s, %s, %s, %s, %s, %s)"""

# %%
for index, row in cr_df.iterrows():
      values = (row['ReviewID'],row['CustomerID'], row['ProductID'], row['ReviewDate'],row['Rating'],row['ReviewText'])
      cursor.execute(insert_query,values)

# %%
connection.commit()

# %%
cursor.execute("""CREATE TABLE customers (
                                        CustomerID INT ,
                                        CustomerName VARCHAR(100),
                                        Email VARCHAR(100),
                                        Gender Varchar(10),
                                        Age INT,
                                        GeographyID INT
                                    );""")

# %%
customer_df.columns
# Out:
# Index(['CustomerID', 'CustomerName', 'Email', 'Gender', 'Age', 'GeographyID'], dtype='object')

# %%
for index, row in customer_df.iterrows():
      values = (row['CustomerID'],row['CustomerName'], row['Email'], row['Gender'],row['Age'],row['GeographyID'])
      print(values)
# Out:
# (1, 'Emma Anderson', 'emma.anderson@example.com', 'Male', 50, 2)
# (2, 'Sarah Brown', 'sarah.brown@example.com', 'Female', 37, 4)
# (3, 'Robert Hernandez', 'robert.hernandez@example.com', 'Female', 26, 6)
# (4, 'David Garcia', 'david.garcia@example.com', 'Male', 25, 8)
# (5, 'Emma Miller', 'emma.miller@example.com', 'Female', 41, 4)
# (6, 'Daniel Rodriguez', 'daniel.rodriguez@example.com', 'Male', 31, 7)
# (7, 'Laura Miller', 'laura.miller@example.com', 'Male', 35, 7)
# (8, 'James Gonzalez', 'james.gonzalez@example.com', 'Female', 18, 8)
# (9, 'Emily Thomas', 'emily.thomas@example.com', 'Male', 29, 10)
# (10, 'Chris Davis', 'chris.davis@example.com', 'Female', 46, 2)
# (11, 'Emma Garcia', 'emma.garcia@example.com', 'Male', 54, 10)
# (12, 'James Lopez', 'james.lopez@example.com', 'Female', 43, 7)
# (13, 'David Wilson', 'david.wilson@example.com', 'Male', 50, 1)
# (14, 'Olivia Wilson', 'olivia.wilson@example.com', 'Male', 60, 4)
# ...

# %%
insert_query = """INSERT INTO customers (CustomerID,CustomerName,Email,Gender,Age,GeographyID) 
VALUES (%s, %s, %s, %s,%s,%s)"""

# %%
for index, row in customer_df.iterrows():
      values = (row['CustomerID'], row['CustomerName'], row['Email'], row['Gender'],
                row['Age'],row['GeographyID'])
      cursor.execute(insert_query,values)

# %%
connection.commit()

# %%
cursor.execute("""CREATE TABLE engagement_data (
                                        EngagementID INT ,
                                        ContentID INT,
                                        ContentType varchar(50),
                                        Likes INT,
                                        EngagementDate DATE,
                                        CampaignID INT,
                                        ProductID INT,
                                        ViewsClicksCombined VARCHAR(50)
                                    );""")

# %%
engagementdata_df.columns
# Out:
# Index(['EngagementID', 'ContentID', 'ContentType', 'Likes', 'EngagementDate',
#        'CampaignID', 'ProductID', 'ViewsClicksCombined'],
#       dtype='object')

# %%
for index, row in engagementdata_df.iterrows():
      values = (row['EngagementID'],row['ContentID'], row['ContentType'], row['Likes'],row['EngagementDate'],row['CampaignID'],row['ProductID'],row['ViewsClicksCombined'])
      print(values)
# Out:
# (1, 39, 'Blog', 190, '2023-08-30', 1, 9, '1883-671')
# (2, 48, 'Blog', 114, '2023-03-28', 18, 20, '5280-532')
# (3, 16, 'video', 32, '2023-12-08', 7, 14, '1905-204')
# (4, 43, 'Video', 17, '2025-01-21', 19, 20, '2766-257')
# (5, 16, 'newsletter', 306, '2024-02-21', 6, 15, '5116-1524')
# (6, 32, 'Socialmedia', 648, '2023-06-18', 18, 19, '8237-1641')
# (7, 33, 'SOCIALMEDIA', 1, '2025-10-01', 12, 2, '750-34')
# (8, 47, 'Blog', 1, '2025-03-31', 17, 6, '891-35')
# (9, 48, 'blog', 123, '2024-03-19', 13, 16, '5571-1527')
# (10, 4, 'Blog', 25, '2023-12-03', 15, 15, '4279-297')
# (11, 38, 'Socialmedia', 29, '2024-05-26', 19, 6, '4297-234')
# (12, 29, 'socialmedia', 396, '2023-06-15', 3, 10, '7877-2037')
# (13, 14, 'video', 12, '2025-02-04', 12, 18, '1796-136')
# (14, 2, 'Socialmedia', 317, '2023-08-26', 16, 2, '6837-2251')
# (15, 16, 'Socialmedia', 0, '2025-10-20', 6, 19, '36-1')
# (16, 2, 'SOCIALMEDIA', 276, '2023-07-06', 17, 16, '5980-1227')
# ...

# %%
insert_query = """INSERT INTO engagement_data (EngagementID,ContentID,ContentType,Likes,EngagementDate,CampaignID,ProductID,ViewsClicksCombined) 
VALUES (%s, %s, %s, %s,%s,%s,%s,%s)"""

# %%
for index, row in engagementdata_df.iterrows():
      values = (row['EngagementID'], row['ContentID'], row['ContentType'], row['Likes'],
                row['EngagementDate'],row['CampaignID'],row['ProductID'],row['ViewsClicksCombined'])
      cursor.execute(insert_query,values)

# %%
connection.commit()

# %%
cursor.execute("""CREATE TABLE geography (
                                        GeographyID INT ,
                                        Country VARCHAR(50),
                                        City varchar (50)
                                    );""")

# %%
geography_df.columns
# Out:
# Index(['GeographyID', 'Country', 'City'], dtype='object')

# %%
insert_query = """INSERT INTO geography(GeographyID,Country,City) 
VALUES (%s, %s, %s)"""

# %%
for index, row in geography_df.iterrows():
      values = (row['GeographyID'], row['Country'], row['City'])
      cursor.execute(insert_query,values)

# %%
connection.commit()

# %%
cursor.execute("""CREATE TABLE products (
                                        ProductID INT ,
                                        ProductName varchar(50),
                                        Category VARCHAR(50),
                                        Price Float
                                    );""")

# %%
products_df.columns
# Out:
# Index(['ProductID', 'ProductName', 'Category', 'Price'], dtype='object')

# %%
for index, row in products_df.iterrows():
      values = (row['ProductID'],row['ProductName'], row['Category'], row['Price'])
      print(values)
# Out:
# (1, 'Running Shoes', 'Sports', 223.75)
# (2, 'Fitness Tracker', 'Sports', 196.68)
# (3, 'Yoga Mat', 'Sports', 485.32)
# (4, 'Dumbbells', 'Sports', 26.21)
# (5, 'Soccer Ball', 'Sports', 41.26)
# (6, 'Tennis Racket', 'Sports', 36.07)
# (7, 'Basketball', 'Sports', 225.12)
# (8, 'Football Helmet', 'Sports', 44.75)
# (9, 'Baseball Glove', 'Sports', 327.36)
# (10, 'Golf Clubs', 'Sports', 81.59)
# (11, 'Ski Boots', 'Sports', 340.2)
# (12, 'Ice Skates', 'Sports', 37.56)
# (13, 'Swim Goggles', 'Sports', 145.97)
# (14, 'Cycling Helmet', 'Sports', 472.32)
# (15, 'Climbing Rope', 'Sports', 410.17)
# (16, 'Kayak', 'Sports', 259.4)
# (17, 'Surfboard', 'Sports', 275.43)
# (18, 'Volleyball', 'Sports', 42.8)
# (19, 'Hockey Stick', 'Sports', 173.83)
# (20, 'Boxing Gloves', 'Sports', 262.32)

# %%
insert_query = """INSERT INTO products (ProductID,ProductName,Category,Price) 
VALUES (%s, %s, %s, %s)"""

# %%
for index, row in products_df.iterrows():
      values = (row['ProductID'], row['ProductName'], row['Category'], row['Price'])
      cursor.execute(insert_query,values)

# %%
connection.commit()

# %% [markdown]
# CUSTOMER FEEDBACK ANALYSIS

# %%
# 1.Factors Influencing customer engagement
engagementdata_df.head(5)
# Out:
#    EngagementID  ContentID ContentType  Likes EngagementDate  CampaignID  \
# 0             1         39        Blog    190     2023-08-30           1
# 1             2         48        Blog    114     2023-03-28          18
# 2             3         16       video     32     2023-12-08           7
# 3             4         43       Video     17     2025-01-21          19
# 4             5         16  newsletter    306     2024-02-21           6
#
#    ProductID ViewsClicksCombined
# 0          9            1883-671
# 1         20            5280-532
# 2         14            1905-204
# 3         20            2766-257
# 4         15           5116-1524

# %%
content_type_engagement = engagementdata_df.groupby('ContentType')['Likes'].mean().reset_index().sort_values(by='Likes', ascending=False)
content_type_engagement
# Out:
#     ContentType       Likes
# 9    newsletter  164.000000
# 7         Video  145.888889
# 0          BLOG  130.833333
# 5   Socialmedia  126.750000
# 1          Blog  121.750000
# 10  socialmedia   90.857143
# 3    Newsletter   89.545455
# 4   SOCIALMEDIA   87.400000
# 11        video   74.818182
# 8          blog   44.333333
# 2    NEWSLETTER   16.750000
# 6         VIDEO   12.000000

# %%
campaign_engagement = engagementdata_df.groupby('CampaignID')['Likes'].mean().reset_index().sort_values(by='Likes', ascending=False)
campaign_engagement
# Out:
#     CampaignID       Likes
# 15          17  212.222222
# 12          14  202.333333
# 5            7  183.833333
# 9           11  165.000000
# 14          16  141.500000
# 16          18  113.375000
# 7            9  105.000000
# 10          12  100.200000
# 1            2   92.666667
# 13          15   92.600000
# 4            6   87.500000
# 6            8   75.750000
# 2            3   74.166667
# 3            4   62.400000
# 0            1   54.285714
# 18          20   53.000000
# 11          13   34.000000
# 17          19    7.714286
# 8           10    0.500000

# %%
# 2.At what stages are customers dropping off in their journey
cj_df.head(5)
# Out:
#    JourneyID  CustomerID  ProductID   VisitDate        Stage    Action  \
# 0          1          64         18  2024-06-10     Checkout  Drop-off
# 1          2          94         11  2025-07-09     Checkout  Drop-off
# 2          3          34          8  2024-06-14  ProductPage      View
# 3          4          33         18  2025-05-28     Checkout  Drop-off
# 4          5          91         10  2023-02-11     Homepage     Click
#
#    Duration
# 0     235.0
# 1     156.0
# 2     235.0
# 3       0.0
# 4     156.0

# %%
drop_offs = cj_df[cj_df['Action'] == 'Drop-off']
drop_offs
# Out:
#     JourneyID  CustomerID  ProductID   VisitDate     Stage    Action  Duration
# 0           1          64         18  2024-06-10  Checkout  Drop-off     235.0
# 1           2          94         11  2025-07-09  Checkout  Drop-off     156.0
# 3           4          33         18  2025-05-28  Checkout  Drop-off       0.0
# 10         11          23         12  2023-08-22  Checkout  Drop-off       0.0
# 20         21          58         20  2024-03-07  Checkout  Drop-off       0.0
# 23         24          77          6  2025-06-25  Checkout  Drop-off       0.0
# 31         32          67         11  2023-09-04  Checkout  Drop-off       0.0
# 36         37          38         17  2024-06-18  Checkout  Drop-off       0.0
# 46         47          30         20  2024-02-18  checkout  Drop-off       0.0
# 51         52          15          9  2025-08-07  Checkout  Drop-off       0.0
# 53         54           9         11  2024-11-19  checkout  Drop-off       0.0
# ...

# %%
drop_off_stages = drop_offs['Stage'].value_counts().reset_index()
drop_off_stages
# Out:
#       Stage  count
# 0  Checkout     12
# 1  checkout      2

# %%
#Common actions leading to sucessful conversions

# %%
cj_df['Action'].unique()
# Out:
# array(['Drop-off', 'View', 'Click', 'Purchase'], dtype=object)

# %%
successful_conversion=cj_df[cj_df['Action']=='Purchase']
successful_conversion
# Out:
#     JourneyID  CustomerID  ProductID   VisitDate     Stage    Action  Duration
# 35         36          17          2  2023-11-20  Checkout  Purchase     137.0
# 75         76          42         17  2025-05-29  Checkout  Purchase     261.0
# 77         78          46         17  2025-06-15  Checkout  Purchase     122.0
# 80         81          89         15  2025-10-27  Checkout  Purchase     246.0
# 83         84          79         15  2025-03-09  Checkout  Purchase      48.0
# 98         99          58         16  2024-07-06  Checkout  Purchase      87.0

# %%
#Average duration per stage 
average_duration_per_stage=cj_df.groupby(['Stage'])['Duration'].mean().reset_index().sort_values(by='Duration',ascending=False)
average_duration_per_stage
# Out:
#          Stage    Duration
# 2  ProductPage  186.666667
# 4     homepage  185.750000
# 1     Homepage  158.520000
# 5  productpage  136.000000
# 0     Checkout   71.777778
# 3     checkout    0.000000

# %%
#3.how do customers reviews impact purchasing behaviour
cr_cj_merged1=pd.merge(cr_df,cj_df)
cr_cj_merged1
# Out:
#    ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0         5          64          2  2023-07-16       3
# 1        84          40         20  2023-07-17       4
# 2        97          64          6  2024-01-19       3
#
#                                           ReviewText  JourneyID   VisitDate  \
# 0            Average  experience,  nothing  special.         82  2025-06-07
# 1           Good  quality,  but  could  be  cheaper.         71  2023-07-13
# 2  The  product  is  okay,  but  the  instruction...         80  2025-04-06
#
#       Stage    Action  Duration
# 0  Homepage     Click     261.0
# 1  Checkout  Drop-off       0.0
# 2  Homepage     Click     161.0

# %%
# 4.which products, locations,and customer segments are performing well
cr_df.head(3)
# Out:
#    ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0         1          77         18  2025-06-20       3
# 1         2          80         19  2024-12-25       5
# 2         3          50         13  2025-01-26       4
#
#                                 ReviewText
# 0  Average  experience,  nothing  special.
# 1           The  quality  is    top-notch.
# 2  Five  stars  for  the  quick  delivery.

# %%
product_review_df=pd.merge(products_df,cr_df)
product_review_df
# Out:
#     ProductID      ProductName Category   Price  ReviewID  CustomerID  \
# 0           1    Running Shoes   Sports  223.75         6          81
# 1           1    Running Shoes   Sports  223.75         7          16
# 2           1    Running Shoes   Sports  223.75        32          91
# 3           1    Running Shoes   Sports  223.75        39          54
# 4           2  Fitness Tracker   Sports  196.68         5          64
# ..        ...              ...      ...     ...       ...         ...
# 95         19     Hockey Stick   Sports  173.83        73          68
# 96         19     Hockey Stick   Sports  173.83        81           3
# 97         19     Hockey Stick   Sports  173.83        88          93
# 98         20    Boxing Gloves   Sports  262.32        25          55
# 99         20    Boxing Gloves   Sports  262.32        84          40
#
#     ReviewDate  Rating                                         ReviewText
# ...

# %%
best_products = product_review_df[product_review_df['Rating'] > 3]
best_products
best_products_Count=best_products.groupby(['ProductID','ProductName'])['Rating'].mean().reset_index().sort_values(by='Rating',ascending=False)
best_products_Count
# Out:
#     ProductID      ProductName    Rating
# 3           4        Dumbbells  5.000000
# 6           8  Football Helmet  5.000000
# 2           3         Yoga Mat  4.750000
# 11         15    Climbing Rope  4.750000
# 5           6    Tennis Racket  4.600000
# 13         17        Surfboard  4.500000
# 8          10       Golf Clubs  4.500000
# 14         18       Volleyball  4.500000
# 15         19     Hockey Stick  4.400000
# 0           1    Running Shoes  4.333333
# 1           2  Fitness Tracker  4.250000
# 9          11        Ski Boots  4.200000
# 4           5      Soccer Ball  4.000000
# 7           9   Baseball Glove  4.000000
# 10         13     Swim Goggles  4.000000
# 12         16            Kayak  4.000000
# 16         20    Boxing Gloves  4.000000

# %%
#Best Location performing well

# %%
customer_cr_merged=pd.merge(cr_df,customer_df,left_on=['CustomerID','Rating'],right_on=['CustomerID','GeographyID'],how='inner')
customer_cr_merged.head(3)
# Out:
#    ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0        15          29         11  2023-01-27       5
# 1        17          88          4  2025-10-29       3
# 2        29          38         13  2023-05-31       4
#
#                                    ReviewText     CustomerName  \
# 0          Great  purchase,  very  satisfied.  Sophia Anderson
# 1                     Not  worth  the  money.      James Brown
# 2  I  love  this  product,  will  buy  again!      John Garcia
#
#                          Email  Gender  Age  GeographyID
# 0  sophia.anderson@example.com  Female   26            5
# 1      james.brown@example.com    Male   42            3
# 2      john.garcia@example.com    Male   28            4

# %%
customer_cr_loc_merged=pd.merge(customer_cr_merged,geography_df,on='GeographyID')
customer_cr_loc_merged.head(3)
# Out:
#    ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0        15          29         11  2023-01-27       5
# 1        17          88          4  2025-10-29       3
# 2        29          38         13  2023-05-31       4
#
#                                    ReviewText     CustomerName  \
# 0          Great  purchase,  very  satisfied.  Sophia Anderson
# 1                     Not  worth  the  money.      James Brown
# 2  I  love  this  product,  will  buy  again!      John Garcia
#
#                          Email  Gender  Age  GeographyID Country    City
# 0  sophia.anderson@example.com  Female   26            5   Italy    Rome
# 1      james.brown@example.com    Male   42            3  France   Paris
# 2      john.garcia@example.com    Male   28            4   Spain  Madrid

# %%
loc_performing_well =customer_cr_loc_merged.groupby(['CustomerID','GeographyID','Country'])['Rating'].mean().reset_index().sort_values(by='Rating',ascending=False)
loc_performing_well
# Out:
#     CustomerID  GeographyID  Country  Rating
# 1           29            5    Italy     5.0
# 6           45            5    Italy     5.0
# 8           54            5    Italy     5.0
# 4           38            4    Spain     4.0
# 2           32            4    Spain     4.0
# 0            2            4    Spain     4.0
# 10          84            4    Spain     4.0
# 12          91            4    Spain     4.0
# 7           49            4    Spain     4.0
# 9           73            4    Spain     4.0
# 13          93            4    Spain     4.0
# 11          88            3   France     3.0
# 5           41            2  Germany     2.0
# 3           35            2  Germany     2.0

# %%
#Customer_Segment_Performing well

cust_segment_df=pd.merge(cr_df,products_df,on='ProductID')
cust_segment_df
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2025-06-20       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# ..       ...         ...        ...         ...     ...
# 95        96          19         13  2023-09-02       3
# 96        97          64          6  2024-01-19       3
# 97        98          96          3  2025-11-20       5
# 98        99          79         16  2025-01-29       2
# 99       100           9          2  2025-06-20       3
#
#                                            ReviewText      ProductName  \
# 0             Average  experience,  nothing  special.       Volleyball
# 1                      The  quality  is    top-notch.     Hockey Stick
# 2             Five  stars  for  the  quick  delivery.     Swim Goggles
# ...

# %%
customer_segment=cust_segment_df[['ProductID','Rating','ProductName']]
customer_segment
# Out:
#     ProductID  Rating      ProductName
# 0          18       3       Volleyball
# 1          19       5     Hockey Stick
# 2          13       4     Swim Goggles
# 3          15       3    Climbing Rope
# 4           2       3  Fitness Tracker
# ..        ...     ...              ...
# 95         13       3     Swim Goggles
# 96          6       3    Tennis Racket
# 97          3       5         Yoga Mat
# 98         16       2            Kayak
# 99          2       3  Fitness Tracker
#
# [100 rows x 3 columns]

# %%
best_customer_segment=cust_segment_df.groupby(['ProductID','ProductName'])['Rating'].mean().reset_index().sort_values(by='Rating',ascending=False)
best_customer_segment
# Out:
#     ProductID      ProductName    Rating
# 7           8  Football Helmet  5.000000
# 17         19     Hockey Stick  4.400000
# 0           1    Running Shoes  4.000000
# 18         20    Boxing Gloves  4.000000
# 16         18       Volleyball  4.000000
# 10         11        Ski Boots  4.000000
# 4           5      Soccer Ball  4.000000
# 13         15    Climbing Rope  4.000000
# 15         17        Surfboard  3.888889
# 5           6    Tennis Racket  3.857143
# 2           3         Yoga Mat  3.714286
# 12         13     Swim Goggles  3.666667
# 1           2  Fitness Tracker  3.571429
# 9          10       Golf Clubs  3.500000
# 8           9   Baseball Glove  3.400000
# 14         16            Kayak  3.400000
# 3           4        Dumbbells  3.000000
# 11         12       Ice Skates  3.000000
# 6           7       Basketball  2.666667

# %%
merged_1 = pd.merge(cr_df, products_df, on='ProductID')
merged_1
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2025-06-20       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# ..       ...         ...        ...         ...     ...
# 95        96          19         13  2023-09-02       3
# 96        97          64          6  2024-01-19       3
# 97        98          96          3  2025-11-20       5
# 98        99          79         16  2025-01-29       2
# 99       100           9          2  2025-06-20       3
#
#                                            ReviewText      ProductName  \
# 0             Average  experience,  nothing  special.       Volleyball
# 1                      The  quality  is    top-notch.     Hockey Stick
# 2             Five  stars  for  the  quick  delivery.     Swim Goggles
# ...

# %%
cust_geo=pd.merge(customer_df,geography_df,on='GeographyID')
cust_geo
# Out:
#     CustomerID      CustomerName                         Email  Gender  Age  \
# 0            1     Emma Anderson     emma.anderson@example.com    Male   50
# 1            2       Sarah Brown       sarah.brown@example.com  Female   37
# 2            3  Robert Hernandez  robert.hernandez@example.com  Female   26
# 3            4      David Garcia      david.garcia@example.com    Male   25
# 4            5       Emma Miller       emma.miller@example.com  Female   41
# ..         ...               ...                           ...     ...  ...
# 95          96    Emily Gonzalez    emily.gonzalez@example.com  Female   38
# 96          97   Emily Rodriguez   emily.rodriguez@example.com  Female   51
# 97          98       Chris Lopez       chris.lopez@example.com  Female   55
# 98          99   Laura Hernandez   laura.hernandez@example.com    Male   41
# 99         100        Jane Brown        jane.brown@example.com  Female   45
#
#     GeographyID      Country       City
# ...

# %%
product_per_region=pd.merge(merged_1,cust_geo,on='CustomerID')
product_per_region
# Out:
#     ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0          1          77         18  2025-06-20       3
# 1          2          80         19  2024-12-25       5
# 2          3          50         13  2025-01-26       4
# 3          4          78         15  2025-04-21       3
# 4          5          64          2  2023-07-16       3
# ..       ...         ...        ...         ...     ...
# 95        96          19         13  2023-09-02       3
# 96        97          64          6  2024-01-19       3
# 97        98          96          3  2025-11-20       5
# 98        99          79         16  2025-01-29       2
# 99       100           9          2  2025-06-20       3
#
#                                            ReviewText      ProductName  \
# 0             Average  experience,  nothing  special.       Volleyball
# 1                      The  quality  is    top-notch.     Hockey Stick
# 2             Five  stars  for  the  quick  delivery.     Swim Goggles
# ...

# %%
#Best Product per region
best_product_per_region = (product_per_region.groupby(['GeographyID', 'Country', 'ProductID', 'ProductName'])['Rating']
    .mean().reset_index().sort_values(by=['GeographyID', 'Country', 'Rating'], ascending=[True, True, False])
    .drop_duplicates(subset=['GeographyID', 'Country']))
best_product_per_region
# Out:
#     GeographyID      Country  ProductID      ProductName    Rating
# 1             1           UK          8  Football Helmet  5.000000
# 4             2      Germany          3         Yoga Mat  5.000000
# 14            3       France         13     Swim Goggles  4.000000
# 23            4        Spain          8  Football Helmet  5.000000
# 35            5        Italy          4        Dumbbells  5.000000
# 47            6  Netherlands         19     Hockey Stick  4.666667
# 50            7      Belgium         10       Golf Clubs  5.000000
# 53            8       Sweden          3         Yoga Mat  5.000000
# 65            9  Switzerland         15    Climbing Rope  5.000000
# 68           10      Austria          3         Yoga Mat  5.000000

# %% [markdown]
# CUSTOMER FEEDBACK ANALYSIS

# %%
#1.Key complaints and improvement areas

# %%
# Complaint Products
complaint_products = merged_1[merged_1['Rating'] <= 3].groupby(['ProductID','ProductName','ReviewText'])['Rating'].mean().reset_index().sort_values(by='Rating',ascending=True)
complaint_products
# Out:
#     ProductID      ProductName  \
# 5           3         Yoga Mat
# 11          6    Tennis Racket
# 10          4        Dumbbells
# 3           2  Fitness Tracker
# 14          7       Basketball
# 28         15    Climbing Rope
# 29         16            Kayak
# 19         10       Golf Clubs
# 32         17        Surfboard
# 7           4        Dumbbells
# 4           3         Yoga Mat
# 6           3         Yoga Mat
# 8           4        Dumbbells
# 2           2  Fitness Tracker
# 1           2  Fitness Tracker
# 9           4        Dumbbells
# 15          7       Basketball
# 13          7       Basketball
# 12          6    Tennis Racket
# 16          9   Baseball Glove
# 20         10       Golf Clubs
# 21         11        Ski Boots
# 17          9   Baseball Glove
# 18          9   Baseball Glove
# 23         12       Ice Skates
# 22         12       Ice Skates
# 24         13     Swim Goggles
# 25         13     Swim Goggles
# 27         15    Climbing Rope
# ...

# %%
#2.Patterns between negative review and product performance

# %%
df1=pd.merge(cr_df,cj_df,how='outer')
df1
# Out:
#      ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0         NaN           1          7         NaN     NaN
# 1         NaN           1         20         NaN     NaN
# 2         NaN           2          2         NaN     NaN
# 3         NaN           2          5         NaN     NaN
# 4        92.0           2         16  2023-11-21     3.0
# ..        ...         ...        ...         ...     ...
# 192      59.0          98          9  2024-09-01     4.0
# 193      80.0          98         16  2025-05-24     3.0
# 194       NaN          99         10         NaN     NaN
# 195       NaN          99         10         NaN     NaN
# 196      24.0         100          4  2025-07-18     3.0
#
#                                        ReviewText  JourneyID   VisitDate  \
# 0                                             NaN       55.0  2024-03-17
# 1                                             NaN       28.0  2025-09-26
# ...

# %%
df2=pd.merge(df1,products_df,how='outer')
df2
# Out:
#      ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0         NaN           9          1         NaN     NaN
# 1         NaN           9          1         NaN     NaN
# 2         NaN          12          1         NaN     NaN
# 3         7.0          16          1  2024-01-29     3.0
# 4         NaN          25          1         NaN     NaN
# ..        ...         ...        ...         ...     ...
# 192      25.0          55         20  2024-12-19     4.0
# 193       NaN          58         20         NaN     NaN
# 194       NaN          69         20         NaN     NaN
# 195       NaN          78         20         NaN     NaN
# 196       NaN          86         20         NaN     NaN
#
#                                             ReviewText  JourneyID   VisitDate  \
# 0                                                  NaN       15.0  2025-11-04
# 1                                                  NaN       19.0  2024-08-15
# ...

# %%
df2.columns
# Out:
# Index(['ReviewID', 'CustomerID', 'ProductID', 'ReviewDate', 'Rating',
#        'ReviewText', 'JourneyID', 'VisitDate', 'Stage', 'Action', 'Duration',
#        'ProductName', 'Category', 'Price'],
#       dtype='object')

# %%
negative_review=df2[df2['Rating']<3].groupby(['ProductID','ProductName','Category','Stage']).mean(numeric_only=True).reset_index().sort_values(by='Rating',ascending=True)
negative_review
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductName, Category, Stage, ReviewID, CustomerID, Rating, JourneyID, Duration, Price]
# Index: []

# %%
# 1. Overall average rating (performance)
overall_rating = df2.groupby(['ProductID', 'ProductName', 'Category'])['Rating'].mean().reset_index()
overall_rating = overall_rating.rename(columns={'Rating': 'OverallRating'})

# 2. Negative review average
negative_review = df2[df2['Rating'] < 3] \
    .groupby(['ProductID', 'ProductName', 'Category'])['Rating'] \
    .mean().reset_index()
negative_review = negative_review.rename(columns={'Rating': 'AvgNegativeRating'})

# 3. % of negative reviews
negative_count = df2[df2['Rating'] < 3].groupby(['ProductID', 'ProductName', 'Category']).size().reset_index(name='NegativeCount')
total_count = df2.groupby(['ProductID', 'ProductName', 'Category']).size().reset_index(name='TotalCount')

# Merge and compute percentage
review_stats = total_count.merge(negative_count, on=['ProductID', 'ProductName', 'Category'], how='left')
review_stats['NegativeCount'] = review_stats['NegativeCount'].fillna(0)
review_stats['NegReviewPercent'] = (review_stats['NegativeCount'] / review_stats['TotalCount']) * 100

# 4. Combine all
product_analysis = overall_rating \
    .merge(negative_review, on=['ProductID', 'ProductName', 'Category'], how='left') \
    .merge(review_stats[['ProductID', 'ProductName', 'Category', 'NegReviewPercent']], on=['ProductID', 'ProductName', 'Category'], how='left')

# %%
complaint_products = merged_1[merged_1['Rating'] <= 3].groupby(['ProductID','ProductName','ReviewText'])['Rating'].mean().reset_index().sort_values(by='Rating',ascending=True)
complaint_products

# %%
#Strategies to enhance customer satisfaction

# %%
cr_cj_merged=pd.merge(cr_df,cj_df)
cr_cj_merged
# Out:
#    ReviewID  CustomerID  ProductID  ReviewDate  Rating  \
# 0         5          64          2  2023-07-16       3
# 1        84          40         20  2023-07-17       4
# 2        97          64          6  2024-01-19       3
#
#                                           ReviewText  JourneyID   VisitDate  \
# 0            Average  experience,  nothing  special.         82  2025-06-07
# 1           Good  quality,  but  could  be  cheaper.         71  2023-07-13
# 2  The  product  is  okay,  but  the  instruction...         80  2025-04-06
#
#       Stage    Action  Duration
# 0  Homepage     Click     261.0
# 1  Checkout  Drop-off       0.0
# 2  Homepage     Click     161.0
